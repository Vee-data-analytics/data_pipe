# %%
! pip install pcb-flow
# Out:
# ERROR: Could not find a version that satisfies the requirement pcb-flow (from versions: none)
# ERROR: No matching distribution found for pcb-flow
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Monde\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from gerber import load_layer
from gerber.render import GerberCairoContext

# Load the Gerber file
gerber_file = load_layer('MICRO-SPACE.GBX')

# Initialize a list to store fiducial coordinates
fiducials = []

# Iterate through the primitives in the Gerber file
for primitive in gerber_file.primitives:
    # Check if the primitive is a circle (common for fiducial marks)
    if primitive.level_polarity == 'dark' and hasattr(primitive, 'diameter'):
        # You might want to adjust this condition based on your specific Gerber file
        if primitive.diameter == 1.0:  # Adjust this value to match your fiducial size
            x, y = primitive.position
            fiducials.append((x, y))

# Print the fiducial coordinates
for i, (x, y) in enumerate(fiducials, 1):
    print(f"Fiducial {i}: X = {x:.6f}, Y = {y:.6f}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from gerber import load_layer
# ----> 2 from gerber.render import GerberCairoContext
#       4 # Load the Gerber file
#       5 gerber_file = load_layer('MICRO-SPACE.GBX')
#
# ImportError: cannot import name 'GerberCairoContext' from 'gerber.render' (C:\Users\Monde\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gerber\render\__init__.py)

# %%
import pandas as pd
import json
import csv




json_data={
{
  "data": {
    "supSearch": {
      "hits": 53,
      "results": [
        {
          "part": {
            "mpn": "NCP03XH103F05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Depth"
                },
                "displayValue": "300 µm"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Lead Free"
                },
                "displayValue": "Lead Free"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "Production (Last Updated: 4 years ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "100 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Radiation Hardening"
                },
                "displayValue": "No"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "10 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Schedule B"
                },
                "displayValue": "8533400080, 8533400080|8533400080|8533400080|8533400080|8533400080"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "1 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              },
              {
                "attribute": {
                  "name": "Width"
                },
                "displayValue": "300 µm"
              }
            ],
            "category": {
              "name": "Thermistors"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03XH103J05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Accuracy"
                },
                "displayValue": "1 %"
              },
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Current Rating"
                },
                "displayValue": "310 µA"
              },
              {
                "attribute": {
                  "name": "Depth"
                },
                "displayValue": "300 µm"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Lead Free"
                },
                "displayValue": "Lead Free"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "Production (Last Updated: 4 years ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "100 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Packaging"
                },
                "displayValue": "Cut Tape (CT)"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Radiation Hardening"
                },
                "displayValue": "No"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "10 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Schedule B"
                },
                "displayValue": "8533400080, 8533400080|8533400080|8533400080|8533400080|8533400080"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "5 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              }
            ],
            "category": {
              "name": "Thermistors"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03WF104F05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Depth"
                },
                "displayValue": "300 µm"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "Production (Last Updated: 4 years ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "32 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "100 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Schedule B"
                },
                "displayValue": "8533400080, 8533400080|8533400080|8533400080|8533400080|8533400080"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "1 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              },
              {
                "attribute": {
                  "name": "Width"
                },
                "displayValue": "300 µm"
              }
            ],
            "category": {
              "name": "Thermistors"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03XM222E05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "NRND (Last Updated: 4 weeks ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "213 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Packaging"
                },
                "displayValue": "Tape & Reel (TR)"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "2.2 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "3 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              },
              {
                "attribute": {
                  "name": "Width"
                },
                "displayValue": "300 µm"
              }
            ],
            "category": {
              "name": "Linear ICs"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03XM222J05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "NRND (Last Updated: 4 weeks ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "213 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Packaging"
                },
                "displayValue": "Tape & Reel (TR)"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "2.2 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "5 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              },
              {
                "attribute": {
                  "name": "Width"
                },
                "displayValue": "300 µm"
              }
            ],
            "category": {
              "name": "Linear ICs"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03WF104J05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Accuracy"
                },
                "displayValue": "1 %"
              },
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Current Rating"
                },
                "displayValue": "100 µA"
              },
              {
                "attribute": {
                  "name": "Depth"
                },
                "displayValue": "300 µm"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Lead Free"
                },
                "displayValue": "Lead Free"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "Production (Last Updated: 4 years ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "32 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Packaging"
                },
                "displayValue": "Tape and Reel"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Radiation Hardening"
                },
                "displayValue": "No"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "100 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Schedule B"
                },
                "displayValue": "8533400080, 8533400080|8533400080|8533400080|8533400080|8533400080"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "5 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              }
            ],
            "category": {
              "name": "Thermistors"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03XH153J05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Accuracy"
                },
                "displayValue": "1 %"
              },
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Current Rating"
                },
                "displayValue": "250 µA"
              },
              {
                "attribute": {
                  "name": "Depth"
                },
                "displayValue": "300 µm"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Lead Free"
                },
                "displayValue": "Lead Free"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "Production (Last Updated: 4 years ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "82 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Packaging"
                },
                "displayValue": "Tape & Reel (TR)"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "15 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Schedule B"
                },
                "displayValue": "8533400080, 8533400080|8533400080|8533400080|8533400080|8533400080"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "5 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              }
            ],
            "category": {
              "name": "Thermistors"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03XM102J05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "NRND (Last Updated: 4 weeks ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "316 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Packaging"
                },
                "displayValue": "Tape & Reel (TR)"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "1 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "5 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              },
              {
                "attribute": {
                  "name": "Width"
                },
                "displayValue": "300 µm"
              }
            ],
            "category": {
              "name": "Linear ICs"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03WB473J05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Accuracy"
                },
                "displayValue": "3 %"
              },
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Current Rating"
                },
                "displayValue": "140 µA"
              },
              {
                "attribute": {
                  "name": "Depth"
                },
                "displayValue": "300 µm"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Lead Free"
                },
                "displayValue": "Lead Free"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "Production (Last Updated: 4 years ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "46 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "47 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Schedule B"
                },
                "displayValue": "8533400080, 8533400080|8533400080|8533400080|8533400080|8533400080"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "5 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              }
            ],
            "category": {
              "name": "Thermistors"
            }
          }
        },
        {
          "part": {
            "mpn": "NCP03WF333J05RL",
            "manufacturer": {
              "name": "Murata"
            },
            "specs": [
              {
                "attribute": {
                  "name": "Accuracy"
                },
                "displayValue": "1 %"
              },
              {
                "attribute": {
                  "name": "Case/Package"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Imperial)"
                },
                "displayValue": "0201"
              },
              {
                "attribute": {
                  "name": "Case Code (Metric)"
                },
                "displayValue": "0603"
              },
              {
                "attribute": {
                  "name": "Current Rating"
                },
                "displayValue": "170 µA"
              },
              {
                "attribute": {
                  "name": "Depth"
                },
                "displayValue": "300 µm"
              },
              {
                "attribute": {
                  "name": "Height"
                },
                "displayValue": "330 µm"
              },
              {
                "attribute": {
                  "name": "Lead Free"
                },
                "displayValue": "Lead Free"
              },
              {
                "attribute": {
                  "name": "Length"
                },
                "displayValue": "600 µm"
              },
              {
                "attribute": {
                  "name": "Lifecycle Status"
                },
                "displayValue": "Production (Last Updated: 4 years ago)"
              },
              {
                "attribute": {
                  "name": "Max Current Rating"
                },
                "displayValue": "55 µA"
              },
              {
                "attribute": {
                  "name": "Max Operating Temperature"
                },
                "displayValue": "125 °C"
              },
              {
                "attribute": {
                  "name": "Max Power Dissipation"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Min Operating Temperature"
                },
                "displayValue": "-40 °C"
              },
              {
                "attribute": {
                  "name": "Mount"
                },
                "displayValue": "Surface Mount"
              },
              {
                "attribute": {
                  "name": "Number of Pins"
                },
                "displayValue": "2"
              },
              {
                "attribute": {
                  "name": "Power Rating"
                },
                "displayValue": "100 mW"
              },
              {
                "attribute": {
                  "name": "Resistance"
                },
                "displayValue": "33 kΩ"
              },
              {
                "attribute": {
                  "name": "RoHS"
                },
                "displayValue": "Compliant"
              },
              {
                "attribute": {
                  "name": "Termination"
                },
                "displayValue": "SMD/SMT"
              },
              {
                "attribute": {
                  "name": "Tolerance"
                },
                "displayValue": "5 %"
              },
              {
                "attribute": {
                  "name": "Voltage Rating"
                },
                "displayValue": "5 V"
              }
            ],
            "category": {
              "name": "Thermistors"
            }
          }
        }
      ]
    }
  },
  "extensions": {
    "requestId": "afc252af-9f98-4442-a2eb-8cc2e769d3f0"
  }
}
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       2 import json
#       3 import csv
# ----> 8 json_data={
#       9 {
#      10   "data": {
#      11     "supSearch": {
#      12       "hits": 53,
#      13       "results": [
#      14         {
#      15           "part": {
#      16             "mpn": "NCP03XH103F05RL",
#      17             "manufacturer": {
#      18               "name": "Murata"
#      19             },
#      20             "specs": [
#      21               {
#      22                 "attribute": {
#      23                   "name": "Case/Package"
#      24                 },
#      25                 "displayValue": "0201"
#      26               },
#      27               {
#      28                 "attribute": {
#      29                   "name": "Case Code (Imperial)"
#      30                 },
# ...

# %%
! pip install gql
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Monde\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/74.0 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/74.0 kB 435.7 kB/s eta 0:00:01
#    ---------------------- ----------------- 41.0/74.0 kB 330.3 kB/s eta 0:00:01
#    -------------------------------------- - 71.7/74.0 kB 438.9 kB/s eta 0:00:01
#    ---------------------------------------- 74.0/74.0 kB 370.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/202.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/202.9 kB ? eta -:--:--
#    ----------- --------------------------- 61.4/202.9 kB 656.4 kB/s eta 0:00:01
#    ----------------- --------------------- 92.2/202.9 kB 751.6 kB/s eta 0:00:01
# ...

# %%
! pip install requests-toolbelt
# Out:
# ...
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.5 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 54.5/54.5 kB 941.3 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Monde\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from gql import gql,Client
from gql.transport.requests import RequestsHTTPTransport
import pandas as pd 

transport  = RequestsHTTPTransport(url="https://api.nexar.com/graphql",headers={"Autthorization:bbe7021a-765b-465d-8d99-ff16c32e3aef"})
client = Client(transport=transport, fetch_schema_from_transport=True)


query = gql("""
query murata0201ResistorSearch {
  supSearch(
    q: "Murata 0201 resistor", 
    filters: {
      manufacturerName: ["Murata"],
      category: ["Chip SMD Resistors"]
    },
    limit: 10
  ) {
    hits
    results {
      part {
        mpn
        manufacturer {
          name
        }
        specs {
          attribute {
            name
          }
          displayValue
        }
        category {
          name
        }
      }
    }
  }
}
""")

response  = client.execute(query)

#Parse response into structured format
data = []
for item in response['supSearch']['results']:
    part = item['part']
    part_data = {
        'MPN':part['mpn'],
        'Manufacture': part 
    }
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 41
#       6 client = Client(transport=transport, fetch_schema_from_transport=True)
#       9 query = gql("""
#      10 query murata0201ResistorSearch {
#      11   supSearch(
#    (...)
#      38 }
#      39 """)
# ---> 41 response  = client.execute(query)
#      43 #Parse response into structured format
#      44 data = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gql\client.py:484, in Client.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     481     return data
#     483 else:  # Sync transports
# --> 484     return self.execute_sync(
#     485         document,
#     486         variable_values=variable_values,
# ...
